# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

tt_list = [train, test]

df = pd.concat(tt_list, sort=False)

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# survival - Survival (0 = No; 1 = Yes)
#
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
#
# name - Name
#
# sex - Sex
#
# age - Age
#
# sibsp - Number of Siblings/Spouses Aboard
#
# parch - Number of Parents/Children Aboard
#
# ticket - Ticket Number
#
# fare - Passenger Fare
#
# cabin - Cabin
#
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
df.hist(bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe40b10cdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe40ac5a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe40a94ab00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe40a5ac908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe40a239080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe40a239400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe407f449b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe408512080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe408520710>]],
#       dtype=object)

# %%
#print(df.head(20))

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# dtype: float64

# %%
#df.info()

# %%
#df.isin([0]).sum(axis=0)

# %% [markdown]
# Almost 40% of Survived is null, 20% of ages are missing, 77% of cabin numbers are missing, and less than 1% of embarked and fare values are missing.

# %%
# replace missing cabin numbers 
df.Cabin = df.Cabin.fillna('UK')

# %%
df.head(10)
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin           0.000000
# Embarked        0.152788
# dtype: float64

# %%
# replace missing fare with median fare
df.Fare = df.Fare.fillna(df.Fare.median())

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin           0.000000
# Embarked        0.152788
# dtype: float64

# %%
# find out counts for embark to find out which one occurs most frequently
embark = df.Embarked.value_counts()
embark
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
# replace embarked with most frequently occuring embarked code
embark = df.Embarked.value_counts().index[0]

df.Embarked = df.Embarked.fillna(embark)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# 25            26       1.0       3
# 26            27       0.0       3
# 27            28       0.0       1
# 28            29       1.0       3
# 29            30       0.0       3
# ..           ...       ...     ...
# 388         1280       NaN       3
# 389         1281       NaN       3
# 390         1282       NaN       1
# 391         1283       NaN       1
# 392         1284       NaN       3
# 393         1285       NaN       2
# 394         1286       NaN       3
# 395         1287       NaN       1
# 396         1288       NaN       3
# 397         1289       NaN       1
# 398         1290       NaN       3
# 399         1291       NaN       3
# 400         1292       NaN       1
# 401         1293       NaN       2
# 402         1294       NaN       1
# 403         1295       NaN       1
# 404         1296       NaN       1
# 405         1297       NaN       2
# 406         1298       NaN       2
# 407         1299       NaN       1
# 408         1300       NaN       3
# 409         1301       NaN       3
# 410         1302       NaN       3
# 411         1303       NaN       1
# 412         1304       NaN       3
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 388                               Canavan, Mr. Patrick    male  21.0      0
# 389                        Palsson, Master. Paul Folke    male   6.0      3
# 390                         Payne, Mr. Vivian Ponsonby    male  23.0      0
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female  51.0      0
# 392                      Abbott, Master. Eugene Joseph    male  13.0      0
# 393                               Gilbert, Mr. William    male  47.0      0
# 394                           Kink-Heilmann, Mr. Anton    male  29.0      3
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0      1
# 396                               Colbert, Mr. Patrick    male  24.0      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# 398                     Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# 399                           Conlon, Mr. Thomas Henry    male  31.0      0
# 400                            Bonnell, Miss. Caroline  female  30.0      0
# 401                                    Gale, Mr. Harry    male  38.0      1
# 402                     Gibson, Miss. Dorothy Winifred  female  22.0      0
# 403                             Carrau, Mr. Jose Pedro    male  17.0      0
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 406                          Ware, Mr. William Jeffery    male  23.0      1
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 408                    Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                          Peacock, Miss. Treasteall  female   3.0      1
# 410                             Naughton, Miss. Hannah  female   NaN      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare        Cabin Embarked
# 0        0           A/5 21171    7.2500           UK        S
# 1        0            PC 17599   71.2833          C85        C
# 2        0    STON/O2. 3101282    7.9250           UK        S
# 3        0              113803   53.1000         C123        S
# 4        0              373450    8.0500           UK        S
# 5        0              330877    8.4583           UK        Q
# 6        0               17463   51.8625          E46        S
# 7        1              349909   21.0750           UK        S
# 8        2              347742   11.1333           UK        S
# 9        0              237736   30.0708           UK        C
# 10       1             PP 9549   16.7000           G6        S
# 11       0              113783   26.5500         C103        S
# 12       0           A/5. 2151    8.0500           UK        S
# 13       5              347082   31.2750           UK        S
# 14       0              350406    7.8542           UK        S
# 15       0              248706   16.0000           UK        S
# 16       1              382652   29.1250           UK        Q
# 17       0              244373   13.0000           UK        S
# 18       0              345763   18.0000           UK        S
# 19       0                2649    7.2250           UK        C
# 20       0              239865   26.0000           UK        S
# 21       0              248698   13.0000          D56        S
# 22       0              330923    8.0292           UK        Q
# 23       0              113788   35.5000           A6        S
# 24       1              349909   21.0750           UK        S
# 25       5              347077   31.3875           UK        S
# 26       0                2631    7.2250           UK        C
# 27       2               19950  263.0000  C23 C25 C27        S
# 28       0              330959    7.8792           UK        Q
# 29       0              349216    7.8958           UK        S
# ..     ...                 ...       ...          ...      ...
# 388      0              364858    7.7500           UK        Q
# 389      1              349909   21.0750           UK        S
# 390      0               12749   93.5000          B24        S
# 391      1            PC 17592   39.4000          D28        S
# 392      2           C.A. 2673   20.2500           UK        S
# 393      0          C.A. 30769   10.5000           UK        S
# 394      1              315153   22.0250           UK        S
# 395      0               13695   60.0000          C31        S
# 396      0              371109    7.2500           UK        Q
# 397      1               13567   79.2000          B41        C
# 398      0              347065    7.7750           UK        S
# 399      0               21332    7.7333           UK        Q
# 400      0               36928  164.8667           C7        S
# 401      0               28664   21.0000           UK        S
# 402      1              112378   59.4000           UK        C
# 403      0              113059   47.1000           UK        S
# 404      0               17765   27.7208          D40        C
# 405      0       SC/PARIS 2166   13.8625          D38        C
# 406      0               28666   10.5000           UK        S
# 407      1              113503  211.5000          C80        C
# 408      0              334915    7.7208           UK        Q
# 409      1  SOTON/O.Q. 3101315   13.7750           UK        S
# 410      0              365237    7.7500           UK        Q
# 411      0               19928   90.0000          C78        Q
# 412      0              347086    7.7750           UK        S
# 413      0           A.5. 3236    8.0500           UK        S
# 414      0            PC 17758  108.9000         C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500           UK        S
# 416      0              359309    8.0500           UK        S
# 417      1                2668   22.3583           UK        C
#
# [1309 rows x 12 columns]
